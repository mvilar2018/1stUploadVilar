# %%
def discovernum():
    for A in range(9):
        for B in range(9):
            for C in range(9):
                for D in range(9):
                    print(A, "," , B",", C,",", D)

discovernum()
# Out:
# 0 , b',' 0 , 0
# 0 , b',' 0 , 1
# 0 , b',' 0 , 2
# 0 , b',' 0 , 3
# 0 , b',' 0 , 4
# 0 , b',' 0 , 5
# 0 , b',' 0 , 6
# 0 , b',' 0 , 7
# 0 , b',' 0 , 8
# 0 , b',' 1 , 0
# 0 , b',' 1 , 1
# 0 , b',' 1 , 2
# 0 , b',' 1 , 3
# 0 , b',' 1 , 4
# 0 , b',' 1 , 5
# 0 , b',' 1 , 6
# 0 , b',' 1 , 7
# 0 , b',' 1 , 8
# 0 , b',' 2 , 0
# 0 , b',' 2 , 1
# 0 , b',' 2 , 2
# 0 , b',' 2 , 3
# 0 , b',' 2 , 4
# 0 , b',' 2 , 5
# 0 , b',' 2 , 6
# 0 , b',' 2 , 7
# 0 , b',' 2 , 8
# 0 , b',' 3 , 0
# 0 , b',' 3 , 1
# 0 , b',' 3 , 2
# 0 , b',' 3 , 3
# 0 , b',' 3 , 4
# 0 , b',' 3 , 5
# 0 , b',' 3 , 6
# 0 , b',' 3 , 7
# 0 , b',' 3 , 8
# 0 , b',' 4 , 0
# 0 , b',' 4 , 1
# 0 , b',' 4 , 2
# 0 , b',' 4 , 3
# 0 , b',' 4 , 4
# 0 , b',' 4 , 5
# 0 , b',' 4 , 6
# 0 , b',' 4 , 7
# 0 , b',' 4 , 8
# 0 , b',' 5 , 0
# 0 , b',' 5 , 1
# 0 , b',' 5 , 2
# 0 , b',' 5 , 3
# 0 , b',' 5 , 4
# 0 , b',' 5 , 5
# 0 , b',' 5 , 6
# 0 , b',' 5 , 7
# 0 , b',' 5 , 8
# 0 , b',' 6 , 0
# 0 , b',' 6 , 1
# 0 , b',' 6 , 2
# 0 , b',' 6 , 3
# ...
